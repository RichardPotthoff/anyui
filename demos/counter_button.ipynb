# %%
import sys
from pathlib import Path

# Get the directory two levels above the current notebook
parent_parent_dir = str(Path().resolve().parents[0])

# Add it to the search path
if parent_parent_dir not in sys.path:
    sys.path.insert(0, parent_parent_dir)
    
from anyui import CounterButton
 
w = CounterButton()
w.value = 60
w
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 11
#       8 if parent_parent_dir not in sys.path:
#       9     sys.path.insert(0, parent_parent_dir)
# ---> 11 from anyui import CounterButton
#      13 w = CounterButton()
#      14 w.value = 60
#
# File /private/var/mobile/Containers/Data/Application/77881549-3FA6-4E4B-803F-D53B172FC865/Documents/anyui/anyui/__init__.py:3
#       1 from .counter_button import CounterButton
#       2 from .box import Box
# ----> 3 from .slider import Slider
#
# File /private/var/mobile/Containers/Data/Application/77881549-3FA6-4E4B-803F-D53B172FC865/Documents/anyui/anyui/slider.py:5
#       2 import traitlets as t
#       3 from pathlib import Path
# ----> 5 class Slider(AnyWidget):
#       6     value = t.Int(50).tag(sync=True)
#       7     min = t.Int(0).tag(sync=True)
#
# ...

# %%
# %ls
# Out:
# WK_anywidget_bridge.py
# box.ipynb
# counter_button.ipynb
# test-counter-button.html
# test-slider.html

# %%
# %ls /private/var/mobile/Containers/Data/Application/77881549-3FA6-4E4B-803F-D53B172FC865/Documents/anyui/anyui/static/
# Out:
# anyui-widget-cls.js
# box-cls.js
# box.js
# counter-button-cls.js
# counter-button.css
# counter-button.js
# mirror.js
# slider-cls.js
# state-manager.js
