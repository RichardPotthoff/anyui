# %%
import sys
from pathlib import Path

# Get the directory two levels above the current notebook
parent_parent_dir = str(Path().resolve().parents[0])

# Add it to the search path
if parent_parent_dir not in sys.path:
    sys.path.insert(0, parent_parent_dir)
    
from anyui import CounterWidget,Box,Box2
 
w = CounterWidget()
w.value = 60

b=Box(children=[w,w])
b
# Out:
# Box(children=[CounterWidget(value=60), CounterWidget(value=60)])
